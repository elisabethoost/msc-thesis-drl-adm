# %%
# notebooks/create_scenarios.ipynb

import sys
sys.path.append("..")   
from scripts.create_data import create_data_scenario
from scripts.logger import log_scenario_folder, mark_log_as_finished, create_new_id
import random
from datetime import datetime
import os

logs_id = create_new_id("scenario")

amount_aircraft = 6
training_or_testing = 'TEMP'
template_folder = "../data/Template"

airports = [
    'AMS', 'CDG', 'FRA', 'LHR', 'MAD', 'MUC', 'ORY', 'TXL', 'VIE', 'ZRH', 
    'BCN', 'BRU', 'CPH', 'DUB', 'IST'
]
aircraft_types = [
    {
        'Model': 'B737', 'Family': 'Boeing', 'Config': '0/0/123', 'Dist': 5000, 
        'Cost/h': 1800.0, 'TurnRound': 30, 'Transit': 30, 'Orig': ['CFE'], 'Maint': ['NULL']
    },
]
config_dict = {
    'DelayCosts': [{'Cabin': 'Economy', 'Type': 'ShortHaul', 'Cost': 100.0}],
    'CancellationCostsOutbound': [{'Cabin': 'Economy', 'Type': 'ShortHaul', 'Cost': 500.0}],
    'CancellationCostsInbound': [{'Cabin': 'Economy', 'Type': 'ShortHaul', 'Cost': 600.0}],
    'DowngradingCosts': [{'FromCabin': 'Business', 'ToCabin': 'Economy', 'Type': 'ShortHaul', 'Cost': 200.0}],
    'PenaltyCosts': [200, 300, 400],
    'Weights': [1.0, 0.5, 0.2],
}

combinations = [
    ("deterministic", "1"),
    ("stochastic", "low"),
    ("stochastic", "medium"),
    ("stochastic", "high"),
    ("mixed", "low"),
    ("mixed", "medium"),
    ("mixed", "high")
]

num_scenarios_per_combination = 100


total_amount_scenarios = len(combinations) * num_scenarios_per_combination
# We will store all scenarios in this single folder
data_root_folder = f"../data/{training_or_testing}/6ac-{total_amount_scenarios}-diverse/"
os.makedirs(data_root_folder, exist_ok=True)

# Collect all outputs for logging at the end
logging_outputs = {}

for probabilistic_type, probabilities_values_type in combinations:
    # Determine disrupted/uncertain counts
    if probabilistic_type == 'stochastic':
        amount_aircraft_disrupted = 0
        amount_aircraft_uncertain = 2
    elif probabilistic_type == 'deterministic':
        amount_aircraft_disrupted = 2
        amount_aircraft_uncertain = 0
    elif probabilistic_type == 'mixed':
        amount_aircraft_disrupted = 1
        amount_aircraft_uncertain = 1
    else:
        raise ValueError(f"Invalid probabilistic_type: {probabilistic_type}")

    # Determine probability bounds
    if probabilistic_type != 'deterministic':
        if probabilities_values_type == 'high':
            prob_lower_bound = 0.5
            prob_upper_bound = 0.9
        elif probabilities_values_type == 'low':
            prob_lower_bound = 0.1
            prob_upper_bound = 0.5
        elif probabilities_values_type == 'medium':
            prob_lower_bound = 0.3
            prob_upper_bound = 0.7
        else:
            raise ValueError(f"Invalid probabilities_values_type: {probabilities_values_type}")
    else:
        prob_lower_bound = 0.0
        prob_upper_bound = 0.0
        probabilities_values_type = 'na'

    logging_inputs = {
        "num_scenarios": num_scenarios_per_combination,
        "aircraft_range": (amount_aircraft, amount_aircraft),
        "amount_aircraft_disrupted": amount_aircraft_disrupted,
        "amount_aircraft_uncertain": amount_aircraft_uncertain,
        "average_flights_per_aircraft": 12,
        "std_dev_flights_per_aircraft": 1,
        "min_delta_start_unavailability": 120,
        "max_delta_start_unavailability": 480,
        "min_period_unavailability": 120,
        "max_period_unavailability": 480,
        "probability_range": (prob_lower_bound, prob_upper_bound),
        "probability_distribution": 'uniform',
        "clear_one_random_aircraft": True,
        "clear_random_flights": True,
        "switch_one_random_flight_to_the_cleared_aircraft": True,
        "first_flight_dep_time_range": (6, 8),
        "flight_length_range": (2, 5),
        "time_between_flights_range": (0, 1),
    }

    for i in range(1, logging_inputs["num_scenarios"] + 1):
        # Scenario naming format: 
        # {probabilistic_type}_{probabilities_values_type}_Scenario_{i:03d}
        scenario_name = f"{probabilistic_type}_{probabilities_values_type}_Scenario_{i:03d}"

        recovery_start_date = datetime(2024, 9, random.randint(1, 30)).strftime('%d/%m/%y')
        recovery_start_time = f'{random.randint(5, 7)}:00'
        recovery_end_date = recovery_start_date
        recovery_end_time = f'{random.randint(20, 23)}:{random.choice(["00", "30"])}'

        data_folder, inputs, outputs = create_data_scenario(
            scenario_name=scenario_name,
            template_folder=template_folder,
            data_root_folder=data_root_folder,
            aircraft_types=aircraft_types,
            total_aircraft_range=logging_inputs["aircraft_range"],
            amount_aircraft_disrupted=logging_inputs["amount_aircraft_disrupted"],
            amount_aircraft_uncertain=logging_inputs["amount_aircraft_uncertain"],
            min_delta_start_unavailability=logging_inputs["min_delta_start_unavailability"],
            max_delta_start_unavailability=logging_inputs["max_delta_start_unavailability"],
            min_period_unavailability=logging_inputs["min_period_unavailability"],
            max_period_unavailability=logging_inputs["max_period_unavailability"],
            average_flights_per_aircraft=logging_inputs["average_flights_per_aircraft"],
            std_dev_flights_per_aircraft=logging_inputs["std_dev_flights_per_aircraft"],
            airports=airports,
            config_dict=config_dict,
            recovery_start_date=recovery_start_date,
            recovery_start_time=recovery_start_time,
            recovery_end_date=recovery_end_date,
            recovery_end_time=recovery_end_time,
            clear_one_random_aircraft=logging_inputs["clear_one_random_aircraft"],
            clear_random_flights=logging_inputs["clear_random_flights"],
            switch_one_random_flight_to_the_cleared_aircraft=logging_inputs["switch_one_random_flight_to_the_cleared_aircraft"],
            probability_range=logging_inputs["probability_range"],
            probability_distribution=logging_inputs["probability_distribution"],
            first_flight_dep_time_range=logging_inputs["first_flight_dep_time_range"],
            flight_length_range=logging_inputs["flight_length_range"],
            time_between_flights_range=logging_inputs["time_between_flights_range"],
        )

        logging_outputs[scenario_name] = outputs

# Log all scenarios together
log_scenario_folder(
    logs_id=logs_id,
    scenario_folder_path=data_root_folder,
    inputs={"combinations": combinations, "per_combination_scenarios": num_scenarios_per_combination, "aircraft": amount_aircraft},
    outputs=logging_outputs
)

# Mark the log as finished
mark_log_as_finished(logs_id, additional_info=data_root_folder)
# Out:
# New ID created: scenario_2
# Data creation for scenario deterministic_na_Scenario_001 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_002 completed with 6 aircraft and 13 flights.
# Data creation for scenario deterministic_na_Scenario_003 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_004 completed with 6 aircraft and 18 flights.
# Data creation for scenario deterministic_na_Scenario_005 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_006 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_007 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_008 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_009 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_010 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_011 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_012 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_013 completed with 6 aircraft and 10 flights.
# Data creation for scenario deterministic_na_Scenario_014 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_015 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_016 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_017 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_018 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_019 completed with 6 aircraft and 18 flights.
# Data creation for scenario deterministic_na_Scenario_020 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_021 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_022 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_023 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_024 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_025 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_026 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_027 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_028 completed with 6 aircraft and 18 flights.
# Data creation for scenario deterministic_na_Scenario_029 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_030 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_031 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_032 completed with 6 aircraft and 13 flights.
# Data creation for scenario deterministic_na_Scenario_033 completed with 6 aircraft and 18 flights.
# Data creation for scenario deterministic_na_Scenario_034 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_035 completed with 6 aircraft and 19 flights.
# Data creation for scenario deterministic_na_Scenario_036 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_037 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_038 completed with 6 aircraft and 19 flights.
# Data creation for scenario deterministic_na_Scenario_039 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_040 completed with 6 aircraft and 18 flights.
# Data creation for scenario deterministic_na_Scenario_041 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_042 completed with 6 aircraft and 12 flights.
# Data creation for scenario deterministic_na_Scenario_043 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_044 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_045 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_046 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_047 completed with 6 aircraft and 19 flights.
# Data creation for scenario deterministic_na_Scenario_048 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_049 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_050 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_051 completed with 6 aircraft and 18 flights.
# Data creation for scenario deterministic_na_Scenario_052 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_053 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_054 completed with 6 aircraft and 18 flights.
# Data creation for scenario deterministic_na_Scenario_055 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_056 completed with 6 aircraft and 18 flights.
# Data creation for scenario deterministic_na_Scenario_057 completed with 6 aircraft and 19 flights.
# Data creation for scenario deterministic_na_Scenario_058 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_059 completed with 6 aircraft and 18 flights.
# Data creation for scenario deterministic_na_Scenario_060 completed with 6 aircraft and 13 flights.
# Data creation for scenario deterministic_na_Scenario_061 completed with 6 aircraft and 19 flights.
# Data creation for scenario deterministic_na_Scenario_062 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_063 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_064 completed with 6 aircraft and 13 flights.
# Data creation for scenario deterministic_na_Scenario_065 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_066 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_067 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_068 completed with 6 aircraft and 13 flights.
# Data creation for scenario deterministic_na_Scenario_069 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_070 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_071 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_072 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_073 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_074 completed with 6 aircraft and 13 flights.
# Data creation for scenario deterministic_na_Scenario_075 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_076 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_077 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_078 completed with 6 aircraft and 19 flights.
# Data creation for scenario deterministic_na_Scenario_079 completed with 6 aircraft and 19 flights.
# Data creation for scenario deterministic_na_Scenario_080 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_081 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_082 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_083 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_084 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_085 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_086 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_087 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_088 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_089 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_090 completed with 6 aircraft and 12 flights.
# Data creation for scenario deterministic_na_Scenario_091 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_092 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_093 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_094 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_095 completed with 6 aircraft and 13 flights.
# Data creation for scenario deterministic_na_Scenario_096 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_097 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_098 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_099 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_100 completed with 6 aircraft and 20 flights.
# Data creation for scenario stochastic_low_Scenario_001 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_low_Scenario_002 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_low_Scenario_003 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_004 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_005 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_low_Scenario_006 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_low_Scenario_007 completed with 6 aircraft and 21 flights.
# Data creation for scenario stochastic_low_Scenario_008 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_low_Scenario_009 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_010 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_011 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_012 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_013 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_low_Scenario_014 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_015 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_low_Scenario_016 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_017 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_018 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_019 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_020 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_low_Scenario_021 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_022 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_023 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_low_Scenario_024 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_025 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_026 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_027 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_028 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_029 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_low_Scenario_030 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_low_Scenario_031 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_032 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_low_Scenario_033 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_034 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_035 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_036 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_037 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_038 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_low_Scenario_039 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_040 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_041 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_042 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_low_Scenario_043 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_low_Scenario_044 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_045 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_low_Scenario_046 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_low_Scenario_047 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_048 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_049 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_low_Scenario_050 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_low_Scenario_051 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_052 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_low_Scenario_053 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_054 completed with 6 aircraft and 20 flights.
# Data creation for scenario stochastic_low_Scenario_055 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_low_Scenario_056 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_low_Scenario_057 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_low_Scenario_058 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_059 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_060 completed with 6 aircraft and 20 flights.
# Data creation for scenario stochastic_low_Scenario_061 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_low_Scenario_062 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_low_Scenario_063 completed with 6 aircraft and 20 flights.
# Data creation for scenario stochastic_low_Scenario_064 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_065 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_066 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_low_Scenario_067 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_068 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_low_Scenario_069 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_low_Scenario_070 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_071 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_072 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_073 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_074 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_low_Scenario_075 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_076 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_077 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_low_Scenario_078 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_079 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_080 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_low_Scenario_081 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_082 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_083 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_084 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_low_Scenario_085 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_low_Scenario_086 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_087 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_088 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_089 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_090 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_low_Scenario_091 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_092 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_093 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_094 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_low_Scenario_095 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_low_Scenario_096 completed with 6 aircraft and 12 flights.
# Data creation for scenario stochastic_low_Scenario_097 completed with 6 aircraft and 21 flights.
# Data creation for scenario stochastic_low_Scenario_098 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_low_Scenario_099 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_100 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_medium_Scenario_001 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_002 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_003 completed with 6 aircraft and 12 flights.
# Data creation for scenario stochastic_medium_Scenario_004 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_005 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_006 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_medium_Scenario_007 completed with 6 aircraft and 21 flights.
# Data creation for scenario stochastic_medium_Scenario_008 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_009 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_010 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_medium_Scenario_011 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_012 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_medium_Scenario_013 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_014 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_015 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_016 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_017 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_medium_Scenario_018 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_019 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_medium_Scenario_020 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_021 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_medium_Scenario_022 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_023 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_024 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_025 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_026 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_medium_Scenario_027 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_028 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_medium_Scenario_029 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_030 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_031 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_032 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_medium_Scenario_033 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_medium_Scenario_034 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_medium_Scenario_035 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_036 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_037 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_038 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_039 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_040 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_041 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_042 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_043 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_044 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_045 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_medium_Scenario_046 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_047 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_medium_Scenario_048 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_049 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_050 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_medium_Scenario_051 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_052 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_medium_Scenario_053 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_medium_Scenario_054 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_055 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_056 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_057 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_058 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_059 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_medium_Scenario_060 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_061 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_062 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_medium_Scenario_063 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_064 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_medium_Scenario_065 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_medium_Scenario_066 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_medium_Scenario_067 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_068 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_069 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_070 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_071 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_072 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_073 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_medium_Scenario_074 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_075 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_medium_Scenario_076 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_077 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_078 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_medium_Scenario_079 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_080 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_081 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_medium_Scenario_082 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_083 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_084 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_085 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_086 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_087 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_088 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_089 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_medium_Scenario_090 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_091 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_092 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_medium_Scenario_093 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_medium_Scenario_094 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_095 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_096 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_097 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_098 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_medium_Scenario_099 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_100 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_high_Scenario_001 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_high_Scenario_002 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_003 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_high_Scenario_004 completed with 6 aircraft and 12 flights.
# Data creation for scenario stochastic_high_Scenario_005 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_006 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_007 completed with 6 aircraft and 20 flights.
# Data creation for scenario stochastic_high_Scenario_008 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_009 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_high_Scenario_010 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_011 completed with 6 aircraft and 10 flights.
# Data creation for scenario stochastic_high_Scenario_012 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_high_Scenario_013 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_014 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_high_Scenario_015 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_016 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_017 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_high_Scenario_018 completed with 6 aircraft and 20 flights.
# Data creation for scenario stochastic_high_Scenario_019 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_020 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_high_Scenario_021 completed with 6 aircraft and 12 flights.
# Data creation for scenario stochastic_high_Scenario_022 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_high_Scenario_023 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_high_Scenario_024 completed with 6 aircraft and 22 flights.
# Data creation for scenario stochastic_high_Scenario_025 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_026 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_027 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_028 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_high_Scenario_029 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_high_Scenario_030 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_high_Scenario_031 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_high_Scenario_032 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_high_Scenario_033 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_high_Scenario_034 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_035 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_036 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_037 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_038 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_039 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_high_Scenario_040 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_041 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_042 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_high_Scenario_043 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_044 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_045 completed with 6 aircraft and 20 flights.
# Data creation for scenario stochastic_high_Scenario_046 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_high_Scenario_047 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_high_Scenario_048 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_high_Scenario_049 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_high_Scenario_050 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_051 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_high_Scenario_052 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_053 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_high_Scenario_054 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_055 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_high_Scenario_056 completed with 6 aircraft and 20 flights.
# Data creation for scenario stochastic_high_Scenario_057 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_058 completed with 6 aircraft and 12 flights.
# Data creation for scenario stochastic_high_Scenario_059 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_060 completed with 6 aircraft and 20 flights.
# Data creation for scenario stochastic_high_Scenario_061 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_high_Scenario_062 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_high_Scenario_063 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_064 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_065 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_high_Scenario_066 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_067 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_068 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_high_Scenario_069 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_high_Scenario_070 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_high_Scenario_071 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_072 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_high_Scenario_073 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_074 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_high_Scenario_075 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_076 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_077 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_078 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_079 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_080 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_081 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_high_Scenario_082 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_083 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_high_Scenario_084 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_085 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_086 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_high_Scenario_087 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_088 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_089 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_high_Scenario_090 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_high_Scenario_091 completed with 6 aircraft and 12 flights.
# Data creation for scenario stochastic_high_Scenario_092 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_high_Scenario_093 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_high_Scenario_094 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_high_Scenario_095 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_096 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_097 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_098 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_high_Scenario_099 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_high_Scenario_100 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_001 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_002 completed with 6 aircraft and 20 flights.
# Data creation for scenario mixed_low_Scenario_003 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_004 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_005 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_006 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_low_Scenario_007 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_008 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_low_Scenario_009 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_010 completed with 6 aircraft and 13 flights.
# Data creation for scenario mixed_low_Scenario_011 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_012 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_013 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_014 completed with 6 aircraft and 20 flights.
# Data creation for scenario mixed_low_Scenario_015 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_low_Scenario_016 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_low_Scenario_017 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_018 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_low_Scenario_019 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_020 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_021 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_022 completed with 6 aircraft and 12 flights.
# Data creation for scenario mixed_low_Scenario_023 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_024 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_025 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_026 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_low_Scenario_027 completed with 6 aircraft and 20 flights.
# Data creation for scenario mixed_low_Scenario_028 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_029 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_030 completed with 6 aircraft and 20 flights.
# Data creation for scenario mixed_low_Scenario_031 completed with 6 aircraft and 12 flights.
# Data creation for scenario mixed_low_Scenario_032 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_low_Scenario_033 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_034 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_035 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_low_Scenario_036 completed with 6 aircraft and 20 flights.
# Data creation for scenario mixed_low_Scenario_037 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_038 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_039 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_040 completed with 6 aircraft and 13 flights.
# Data creation for scenario mixed_low_Scenario_041 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_low_Scenario_042 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_043 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_044 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_045 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_046 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_047 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_048 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_049 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_050 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_low_Scenario_051 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_052 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_053 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_054 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_low_Scenario_055 completed with 6 aircraft and 13 flights.
# Data creation for scenario mixed_low_Scenario_056 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_low_Scenario_057 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_low_Scenario_058 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_059 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_060 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_061 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_062 completed with 6 aircraft and 13 flights.
# Data creation for scenario mixed_low_Scenario_063 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_low_Scenario_064 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_065 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_066 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_low_Scenario_067 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_low_Scenario_068 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_069 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_low_Scenario_070 completed with 6 aircraft and 10 flights.
# Data creation for scenario mixed_low_Scenario_071 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_072 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_073 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_074 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_075 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_076 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_077 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_078 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_079 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_080 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_081 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_082 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_083 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_low_Scenario_084 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_085 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_086 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_087 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_088 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_low_Scenario_089 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_090 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_091 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_low_Scenario_092 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_093 completed with 6 aircraft and 14 flights.
# ...
# Data creation for scenario mixed_medium_Scenario_033 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_medium_Scenario_034 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_035 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_036 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_medium_Scenario_037 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_medium_Scenario_038 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_039 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_040 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_medium_Scenario_041 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_medium_Scenario_042 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_medium_Scenario_043 completed with 6 aircraft and 13 flights.
# Data creation for scenario mixed_medium_Scenario_044 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_medium_Scenario_045 completed with 6 aircraft and 12 flights.
# Data creation for scenario mixed_medium_Scenario_046 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_047 completed with 6 aircraft and 12 flights.
# Data creation for scenario mixed_medium_Scenario_048 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_medium_Scenario_049 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_050 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_051 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_medium_Scenario_052 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_053 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_medium_Scenario_054 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_medium_Scenario_055 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_medium_Scenario_056 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_medium_Scenario_057 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_058 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_medium_Scenario_059 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_medium_Scenario_060 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_medium_Scenario_061 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_medium_Scenario_062 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_063 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_medium_Scenario_064 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_medium_Scenario_065 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_066 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_medium_Scenario_067 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_068 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_medium_Scenario_069 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_070 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_medium_Scenario_071 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_072 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_073 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_medium_Scenario_074 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_medium_Scenario_075 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_medium_Scenario_076 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_077 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_medium_Scenario_078 completed with 6 aircraft and 13 flights.
# Data creation for scenario mixed_medium_Scenario_079 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_medium_Scenario_080 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_medium_Scenario_081 completed with 6 aircraft and 13 flights.
# Data creation for scenario mixed_medium_Scenario_082 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_medium_Scenario_083 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_084 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_medium_Scenario_085 completed with 6 aircraft and 20 flights.
# Data creation for scenario mixed_medium_Scenario_086 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_medium_Scenario_087 completed with 6 aircraft and 13 flights.
# Data creation for scenario mixed_medium_Scenario_088 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_089 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_090 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_medium_Scenario_091 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_092 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_093 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_094 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_095 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_096 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_097 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_098 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_099 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_medium_Scenario_100 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_001 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_002 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_003 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_high_Scenario_004 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_high_Scenario_005 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_006 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_high_Scenario_007 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_008 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_009 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_high_Scenario_010 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_011 completed with 6 aircraft and 20 flights.
# Data creation for scenario mixed_high_Scenario_012 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_013 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_014 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_high_Scenario_015 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_016 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_high_Scenario_017 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_018 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_high_Scenario_019 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_020 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_021 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_022 completed with 6 aircraft and 13 flights.
# Data creation for scenario mixed_high_Scenario_023 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_024 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_high_Scenario_025 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_high_Scenario_026 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_027 completed with 6 aircraft and 11 flights.
# Data creation for scenario mixed_high_Scenario_028 completed with 6 aircraft and 12 flights.
# Data creation for scenario mixed_high_Scenario_029 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_030 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_high_Scenario_031 completed with 6 aircraft and 20 flights.
# Data creation for scenario mixed_high_Scenario_032 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_high_Scenario_033 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_high_Scenario_034 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_035 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_036 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_037 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_high_Scenario_038 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_high_Scenario_039 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_040 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_041 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_042 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_043 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_044 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_high_Scenario_045 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_046 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_047 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_high_Scenario_048 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_049 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_high_Scenario_050 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_high_Scenario_051 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_high_Scenario_052 completed with 6 aircraft and 20 flights.
# Data creation for scenario mixed_high_Scenario_053 completed with 6 aircraft and 13 flights.
# Data creation for scenario mixed_high_Scenario_054 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_055 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_056 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_high_Scenario_057 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_high_Scenario_058 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_059 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_060 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_061 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_high_Scenario_062 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_063 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_064 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_065 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_high_Scenario_066 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_high_Scenario_067 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_068 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_high_Scenario_069 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_070 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_071 completed with 6 aircraft and 19 flights.
# Data creation for scenario mixed_high_Scenario_072 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_073 completed with 6 aircraft and 13 flights.
# Data creation for scenario mixed_high_Scenario_074 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_075 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_076 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_077 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_078 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_079 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_080 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_081 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_082 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_high_Scenario_083 completed with 6 aircraft and 13 flights.
# Data creation for scenario mixed_high_Scenario_084 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_085 completed with 6 aircraft and 13 flights.
# Data creation for scenario mixed_high_Scenario_086 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_087 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_088 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_high_Scenario_089 completed with 6 aircraft and 20 flights.
# Data creation for scenario mixed_high_Scenario_090 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_091 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_092 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_093 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_094 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_095 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_high_Scenario_096 completed with 6 aircraft and 20 flights.
# Data creation for scenario mixed_high_Scenario_097 completed with 6 aircraft and 18 flights.
# Data creation for scenario mixed_high_Scenario_098 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_high_Scenario_099 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_high_Scenario_100 completed with 6 aircraft and 18 flights.
# Scenario logged to ../logs/scenarios/scenario_folder_scenario_2.json
# Warning: logs_id scenario_2 not found in ids.json
# Marked logs_id scenario_2 as finished in ../logs/ids.json
