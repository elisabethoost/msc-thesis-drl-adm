# %%
# notebooks/create_scenarios.ipynb

import sys
sys.path.append("..")   
from scripts.create_data import create_data_scenario
from scripts.logger import log_scenario_folder, mark_log_as_finished, create_new_id
import random
from datetime import datetime
import os

logs_id = create_new_id("scenario")

amount_aircraft = 6
training_or_testing = 'Training'
template_folder = "../data/Template"

airports = [
    'AMS', 'CDG', 'FRA', 'LHR', 'MAD', 'MUC', 'ORY', 'TXL', 'VIE', 'ZRH', 
    'BCN', 'BRU', 'CPH', 'DUB', 'IST'
]
aircraft_types = [
    {
        'Model': 'B737', 'Family': 'Boeing', 'Config': '0/0/123', 'Dist': 5000, 
        'Cost/h': 1800.0, 'TurnRound': 30, 'Transit': 30, 'Orig': ['CFE'], 'Maint': ['NULL']
    },
]
config_dict = {
    'DelayCosts': [{'Cabin': 'Economy', 'Type': 'ShortHaul', 'Cost': 100.0}],
    'CancellationCostsOutbound': [{'Cabin': 'Economy', 'Type': 'ShortHaul', 'Cost': 500.0}],
    'CancellationCostsInbound': [{'Cabin': 'Economy', 'Type': 'ShortHaul', 'Cost': 600.0}],
    'DowngradingCosts': [{'FromCabin': 'Business', 'ToCabin': 'Economy', 'Type': 'ShortHaul', 'Cost': 200.0}],
    'PenaltyCosts': [200, 300, 400],
    'Weights': [1.0, 0.5, 0.2],
}

combinations = [
    ("deterministic", "1"),
    ("deterministic", "1"),
    ("deterministic", "1"),
    ("deterministic", "2"),
    ("stochastic", "low"),
    ("stochastic", "medium"),
    ("stochastic", "high"),
    ("mixed", "low"),
    ("mixed", "medium"),
    ("mixed", "high")
]

num_scenarios_per_combination = 10


total_amount_scenarios = len(combinations) * num_scenarios_per_combination
# We will store all scenarios in this single folder
data_root_folder = f"../data/{training_or_testing}/6ac-{total_amount_scenarios}-superdiverse/"
os.makedirs(data_root_folder, exist_ok=True)

# Collect all outputs for logging at the end
logging_outputs = {}

for probabilistic_type, probabilities_values_type in combinations:
    # Determine disrupted/uncertain counts
    if probabilistic_type == 'stochastic':
        amount_aircraft_disrupted = 0
        amount_aircraft_uncertain = 2
    elif probabilistic_type == 'deterministic':
        if probabilities_values_type == '1':
            amount_aircraft_disrupted = 1
            amount_aircraft_uncertain = 0
        elif probabilities_values_type == '2':
            amount_aircraft_disrupted = 2
            amount_aircraft_uncertain = 0
        else:
            raise ValueError(f"Invalid probabilities_values_type: {probabilities_values_type}")
    elif probabilistic_type == 'mixed':
        amount_aircraft_disrupted = 1
        amount_aircraft_uncertain = 1
    else:
        raise ValueError(f"Invalid probabilistic_type: {probabilistic_type}")

    # Determine probability bounds
    if probabilistic_type != 'deterministic':
        if probabilities_values_type == 'high':
            prob_lower_bound = 0.5
            prob_upper_bound = 0.9
        elif probabilities_values_type == 'low':
            prob_lower_bound = 0.1
            prob_upper_bound = 0.5
        elif probabilities_values_type == 'medium':
            prob_lower_bound = 0.3
            prob_upper_bound = 0.7
        else:
            raise ValueError(f"Invalid probabilities_values_type: {probabilities_values_type}")
    else:
        prob_lower_bound = 0.0
        prob_upper_bound = 0.0
        probabilities_values_type = 'na'

    logging_inputs = {
        "num_scenarios": num_scenarios_per_combination,
        "aircraft_range": (amount_aircraft, amount_aircraft),
        "amount_aircraft_disrupted": amount_aircraft_disrupted,
        "amount_aircraft_uncertain": amount_aircraft_uncertain,
        "average_flights_per_aircraft": 12,
        "std_dev_flights_per_aircraft": 1,
        "min_delta_start_unavailability": 120,
        "max_delta_start_unavailability": 480,
        "min_period_unavailability": 120,
        "max_period_unavailability": 480,
        "probability_range": (prob_lower_bound, prob_upper_bound),
        "probability_distribution": 'uniform',
        "clear_one_random_aircraft": True,
        "clear_random_flights": True,
        "switch_one_random_flight_to_the_cleared_aircraft": True,
        "first_flight_dep_time_range": (6, 8),
        "flight_length_range": (2, 5),
        "time_between_flights_range": (0, 1),
    }

    for i in range(1, logging_inputs["num_scenarios"] + 1):
        # Scenario naming format: 
        # {probabilistic_type}_{probabilities_values_type}_Scenario_{i:03d}
        scenario_name = f"{probabilistic_type}_{probabilities_values_type}_Scenario_{i:03d}"

        recovery_start_date = datetime(2024, 9, random.randint(1, 30)).strftime('%d/%m/%y')
        recovery_start_time = f'{random.randint(5, 7)}:00'
        recovery_end_date = recovery_start_date
        recovery_end_time = f'{random.randint(20, 23)}:{random.choice(["00", "30"])}'

        data_folder, inputs, outputs = create_data_scenario(
            scenario_name=scenario_name,
            template_folder=template_folder,
            data_root_folder=data_root_folder,
            aircraft_types=aircraft_types,
            total_aircraft_range=logging_inputs["aircraft_range"],
            amount_aircraft_disrupted=logging_inputs["amount_aircraft_disrupted"],
            amount_aircraft_uncertain=logging_inputs["amount_aircraft_uncertain"],
            min_delta_start_unavailability=logging_inputs["min_delta_start_unavailability"],
            max_delta_start_unavailability=logging_inputs["max_delta_start_unavailability"],
            min_period_unavailability=logging_inputs["min_period_unavailability"],
            max_period_unavailability=logging_inputs["max_period_unavailability"],
            average_flights_per_aircraft=logging_inputs["average_flights_per_aircraft"],
            std_dev_flights_per_aircraft=logging_inputs["std_dev_flights_per_aircraft"],
            airports=airports,
            config_dict=config_dict,
            recovery_start_date=recovery_start_date,
            recovery_start_time=recovery_start_time,
            recovery_end_date=recovery_end_date,
            recovery_end_time=recovery_end_time,
            clear_one_random_aircraft=logging_inputs["clear_one_random_aircraft"],
            clear_random_flights=logging_inputs["clear_random_flights"],
            switch_one_random_flight_to_the_cleared_aircraft=logging_inputs["switch_one_random_flight_to_the_cleared_aircraft"],
            probability_range=logging_inputs["probability_range"],
            probability_distribution=logging_inputs["probability_distribution"],
            first_flight_dep_time_range=logging_inputs["first_flight_dep_time_range"],
            flight_length_range=logging_inputs["flight_length_range"],
            time_between_flights_range=logging_inputs["time_between_flights_range"],
        )

        logging_outputs[scenario_name] = outputs

# Log all scenarios together
log_scenario_folder(
    logs_id=logs_id,
    scenario_folder_path=data_root_folder,
    inputs={"combinations": combinations, "per_combination_scenarios": num_scenarios_per_combination, "aircraft": amount_aircraft},
    outputs=logging_outputs
)

# Mark the log as finished
mark_log_as_finished(logs_id, additional_info=data_root_folder)
# Out:
# New ID created: scenario_17
# Data creation for scenario deterministic_na_Scenario_001 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_002 completed with 6 aircraft and 19 flights.
# Data creation for scenario deterministic_na_Scenario_003 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_004 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_005 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_006 completed with 6 aircraft and 18 flights.
# Data creation for scenario deterministic_na_Scenario_007 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_008 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_009 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_010 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_001 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_002 completed with 6 aircraft and 13 flights.
# Data creation for scenario deterministic_na_Scenario_003 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_004 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_005 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_006 completed with 6 aircraft and 19 flights.
# Data creation for scenario deterministic_na_Scenario_007 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_008 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_009 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_010 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_001 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_002 completed with 6 aircraft and 13 flights.
# Data creation for scenario deterministic_na_Scenario_003 completed with 6 aircraft and 13 flights.
# Data creation for scenario deterministic_na_Scenario_004 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_005 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_006 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_007 completed with 6 aircraft and 18 flights.
# Data creation for scenario deterministic_na_Scenario_008 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_009 completed with 6 aircraft and 18 flights.
# Data creation for scenario deterministic_na_Scenario_010 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_001 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_002 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_003 completed with 6 aircraft and 18 flights.
# Data creation for scenario deterministic_na_Scenario_004 completed with 6 aircraft and 15 flights.
# Data creation for scenario deterministic_na_Scenario_005 completed with 6 aircraft and 17 flights.
# Data creation for scenario deterministic_na_Scenario_006 completed with 6 aircraft and 18 flights.
# Data creation for scenario deterministic_na_Scenario_007 completed with 6 aircraft and 16 flights.
# Data creation for scenario deterministic_na_Scenario_008 completed with 6 aircraft and 13 flights.
# Data creation for scenario deterministic_na_Scenario_009 completed with 6 aircraft and 14 flights.
# Data creation for scenario deterministic_na_Scenario_010 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_low_Scenario_001 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_002 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_003 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_004 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_005 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_006 completed with 6 aircraft and 13 flights.
# Data creation for scenario stochastic_low_Scenario_007 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_low_Scenario_008 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_low_Scenario_009 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_low_Scenario_010 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_medium_Scenario_001 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_002 completed with 6 aircraft and 12 flights.
# Data creation for scenario stochastic_medium_Scenario_003 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_004 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_medium_Scenario_005 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_006 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_007 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_medium_Scenario_008 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_medium_Scenario_009 completed with 6 aircraft and 19 flights.
# Data creation for scenario stochastic_medium_Scenario_010 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_high_Scenario_001 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_high_Scenario_002 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_003 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_high_Scenario_004 completed with 6 aircraft and 14 flights.
# Data creation for scenario stochastic_high_Scenario_005 completed with 6 aircraft and 16 flights.
# Data creation for scenario stochastic_high_Scenario_006 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_007 completed with 6 aircraft and 15 flights.
# Data creation for scenario stochastic_high_Scenario_008 completed with 6 aircraft and 18 flights.
# Data creation for scenario stochastic_high_Scenario_009 completed with 6 aircraft and 17 flights.
# Data creation for scenario stochastic_high_Scenario_010 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_001 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_002 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_low_Scenario_003 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_004 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_005 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_006 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_007 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_low_Scenario_008 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_009 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_low_Scenario_010 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_medium_Scenario_001 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_medium_Scenario_002 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_003 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_004 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_medium_Scenario_005 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_medium_Scenario_006 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_007 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_medium_Scenario_008 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_medium_Scenario_009 completed with 6 aircraft and 20 flights.
# Data creation for scenario mixed_medium_Scenario_010 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_001 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_002 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_003 completed with 6 aircraft and 14 flights.
# Data creation for scenario mixed_high_Scenario_004 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_005 completed with 6 aircraft and 15 flights.
# Data creation for scenario mixed_high_Scenario_006 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_007 completed with 6 aircraft and 13 flights.
# Data creation for scenario mixed_high_Scenario_008 completed with 6 aircraft and 16 flights.
# Data creation for scenario mixed_high_Scenario_009 completed with 6 aircraft and 17 flights.
# Data creation for scenario mixed_high_Scenario_010 completed with 6 aircraft and 14 flights.
# Scenario logged to ../logs/scenarios/scenario_folder_scenario_17.json
# Warning: logs_id scenario_17 not found in ids.json
# Marked logs_id scenario_17 as finished in ../logs/ids.json
