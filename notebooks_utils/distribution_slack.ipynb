# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline
import seaborn as sns
sns.set_theme(style="darkgrid")

# Data from comments
buckets = [
    '0.315-0.320', '0.320-0.325', '0.325-0.330', '0.330-0.335', '0.335-0.340',
    '0.340-0.345', '0.345-0.350', '0.350-0.355', '0.355-0.360', '0.360-0.365',
    '0.365-0.370', '0.370-0.375', '0.375-0.380', '0.380-0.385', '0.385-0.390',
    '0.390-0.395', '0.395-0.400', '0.400-0.405', '0.405-0.410', '0.410-0.415',
    '0.415-0.420', '0.420-0.425', '0.425-0.430', '0.430-0.435', '0.435-0.440',
    '0.440-0.445', '0.445-0.450', '0.450-0.455', '0.455-0.460', '0.460-0.465',
    '0.465-0.470', '0.470-0.475', '0.475-0.480', '0.480-0.485', '0.485-0.490',
    '0.490-0.495', '0.495-0.500', '0.500-0.505', '0.505-0.510', '0.510-0.515',
    '0.515-0.520', '0.520-0.525', '0.525-0.530', '0.530-0.535', '0.535-0.540'
]

scenarios = [2, 1, 5, 4, 6, 3, 13, 11, 10, 11, 18, 20, 26, 36, 27, 30, 34, 32, 31, 32,
            34, 33, 28, 32, 21, 29, 25, 16, 25, 18, 13, 17, 8, 13, 8, 8, 2, 3, 4, 3,
            2, 2, 1, 2, 0]

# Create the histogram
plt.figure(figsize=(10, 6))

plt.bar(range(len(buckets)), scenarios, align='center', alpha=0.8)

# Customize the plot
plt.title('Distribution of scenarios across slack values')
plt.xlabel('Slack range')
plt.ylabel('Number of scenarios')
plt.grid(True)
# Show every other tick to halve the amount shown
plt.xticks(range(0, len(buckets), 2), [buckets[i] for i in range(0, len(buckets), 2)], rotation=45)

plt.tight_layout()
plt.show()
