# %%
import sys
sys.path.append("..")
import os
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
from scripts.utils import *
from scripts.visualizations import *
from src.config import *
from datetime import datetime, timedelta
from src.environment import AircraftDisruptionEnv
from scripts.visualizations import StatePlotter
from src.config import TIMESTEP_HOURS
import time


# Run the random agent
def run_random_agent(scenario_folder):
    # Set a random seed based on the current second in time
    current_seed = int(time.time() * 1e9) % (2**32 - 1)
    print(current_seed)
    np.random.seed(current_seed)

    # Load the scenario data
    data_dict = load_scenario_data(scenario_folder)

    # Extract necessary data for the environment
    aircraft_dict = data_dict['aircraft']
    flights_dict = data_dict['flights']
    rotations_dict = data_dict['rotations']
    alt_aircraft_dict = data_dict['alt_aircraft']
    config_dict = data_dict['config']

    # Initialize the environment
    env = AircraftDisruptionEnv(aircraft_dict, flights_dict, rotations_dict, alt_aircraft_dict, config_dict,  env_type=env_type)
    # Removed DummyVecEnv wrapping

    # Reset the environment
    obs, info = env.reset()
    if DEBUG_MODE_VISUALIZATION:
        print("Observation keys:", obs.keys())

    done = False
    total_reward = 0
    step_num = 0

    # Create StatePlotter object for visualizing the environment state
    state_plotter = StatePlotter(
        aircraft_dict=env.aircraft_dict,
        flights_dict=env.flights_dict,
        rotations_dict=env.rotations_dict,
        alt_aircraft_dict=env.alt_aircraft_dict,
        start_datetime=env.start_datetime,
        end_datetime=env.end_datetime,
        uncertain_breakdowns=env.uncertain_breakdowns,
    )

    # Print state nicely
    print("Initial State:")

    while not done:
        # Visualize the environment at each step
        print(f"Step {step_num}:")

        # Extract necessary information from the environment for plotting
        swapped_flights = env.swapped_flights
        environment_delayed_flights = env.environment_delayed_flights
        current_datetime = env.current_datetime

        # Retrieve the updated dictionaries from the environment
        updated_flights_dict = env.flights_dict
        updated_rotations_dict = env.rotations_dict
        updated_alt_aircraft_dict = env.alt_aircraft_dict
        cancelled_flights = env.penalized_cancelled_flights

        if DEBUG_MODE_VISUALIZATION:
            print("Flights Dict:")
            print(updated_flights_dict)
            print("Alt Aircraft Dict:")
            print(updated_alt_aircraft_dict)
            print("Swapped Flights:")
            print(swapped_flights)
            print("Environment Delayed Flights:")
            print(environment_delayed_flights)
            print("Cancelled Flights:")
            print(cancelled_flights)
            print("Unavailabilities:")
            print(env.alt_aircraft_dict)
            print("Uncertain Breakdowns:")
            for key, value in env.uncertain_breakdowns.items():
                print(f"{key}: {value}")
            print("Current Breakdowns:")
            print(env.current_breakdowns)
            print("")

        # Update the StatePlotter's dictionaries with the updated ones
        state_plotter.alt_aircraft_dict = updated_alt_aircraft_dict
        state_plotter.flights_dict = updated_flights_dict
        state_plotter.rotations_dict = updated_rotations_dict

        # Plot the state using the updated dictionaries
        state_plotter.plot_state(
            updated_flights_dict, swapped_flights, environment_delayed_flights, cancelled_flights, current_datetime
        )


        # Get the action mask from the environment
        action_mask = np.array(obs['action_mask'], dtype=float)
        print(f"action_mask: {len(action_mask)}")
        print(f"len action mask where value is 1: {len(np.where(action_mask == 1)[0])}")
        print(f"at current datetime: {current_datetime}")
        np.set_printoptions(suppress=True, precision=1)

        # Convert observation to float32
        obs = {key: np.array(value, dtype=np.float32) for key, value in obs.items()}
        print_state_nicely(env.state, env_type)
        print("")
        # Select an action        
        valid_actions = np.where(action_mask == 1)[0]
        action_index = np.random.choice(valid_actions)  # Randomly select from valid actions

        # print("Valid actions:")
        # print(valid_actions)
        # print("")
        # print("Valid actions:")
        # for action in valid_actions:
        #     print(f"Action {action}: {env.map_index_to_action(action)}")
        # print("")
        # print(f"Action index: {action_index}")

        action = env.map_index_to_action(action_index)
        print(f"Action: Flight {action[0]}, Aircraft {action[1]}")

        
        # Step the environment
        obs, reward, terminated, truncated, info = env.step(action_index)  # Pass the scalar action index

        # Determine if the episode is done
        done = terminated or truncated

        # Accumulate the reward
        total_reward += reward

        # Print action taken and reward
        action = env.map_index_to_action(action_index)
        print(f"Action taken: Flight {action[0]}, Aircraft {action[1]}, Reward: {reward}")
        print("")

        step_num += 1

    # Final plot after the simulation ends
    state_plotter.plot_state(
        updated_flights_dict, swapped_flights, environment_delayed_flights, cancelled_flights, current_datetime+timedelta(hours=TIMESTEP_HOURS)
    )

    print(f"Total Reward: {total_reward}")

env_type = "proactive"

SCENARIO_FOLDER = "../data/Training/6ac-1-deterministic/Scenario_00001"

# Verify folder exists
if not os.path.exists(SCENARIO_FOLDER):
    raise FileNotFoundError(f"Scenario folder not found: {SCENARIO_FOLDER}")

# Run the random agent
run_random_agent(SCENARIO_FOLDER)
# Out:
# 2288219335
# Initial State:
# Step 0:
# action_mask: 126
# len action mask where value is 1: 106
# at current datetime: 2024-09-20 07:00:00
#
# State for:  proactive
# │ Current Time       │ Time Until End     │
# │          0         │          0         │
#
#   AC   Prob  Start   End |    F1  Dep1  Arr1 |    F2  Dep2  Arr2 |    F3  Dep3  Arr3 |    F4  Dep4  Arr4 |    F5  Dep5  Arr5 |    F6  Dep6  Arr6 |    F7  Dep7  Arr7 |    F8  Dep8  Arr8 |    F9  Dep9  Arr9 |   F10 Dep10 Arr10 |   F11 Dep11 Arr11 |   F12 Dep12 Arr12 |   F13 Dep13 Arr13 |   F14 Dep14 Arr14 |   F15 Dep15 Arr15 |   F16 Dep16 Arr16 |   F17 Dep17 Arr17
#    1      -      -     - |     1    45   301 |     2   301   514 |     3   514   711 |     4   711   882 |     5   882  1116 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    2      -      -     - |     6    60   200 |     7   265   441 |     8   543   726 |     9   726   853 |    10   853  1133 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    3   1.00    177   626 |    11    60   349 |    12   349   471 |    14   695   895 |    15   895  1047 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    4      -      -     - |    13   471   695 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    5      -      -     - |    21    45   245 |    22   245   521 |    23   521   672 |    24   672   832 |    25   832  1099 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    6      -      -     - |    26   105   351 |    27   351   519 |    28   519   647 |    29   647   924 |    30   924  1142 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#
# Action: Flight 9, Aircraft 3
#
# Calculating reward for action: flight 9, aircraft 3
#   -14800.0 penalty for 296.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +36.300000000000004 bonus for proactive action (726.0 minutes ahead)
#   -6.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -14869.7
# --------------------------------
# Action taken: Flight 9, Aircraft 3, Reward: -14869.7
#
# Step 1:
# action_mask: 126
# len action mask where value is 1: 99
# at current datetime: 2024-09-20 08:00:00
#
# State for:  proactive
# │ Current Time       │ Time Until End     │
# │         60         │         60         │
#
#   AC   Prob  Start   End |    F1  Dep1  Arr1 |    F2  Dep2  Arr2 |    F3  Dep3  Arr3 |    F4  Dep4  Arr4 |    F5  Dep5  Arr5 |    F6  Dep6  Arr6 |    F7  Dep7  Arr7 |    F8  Dep8  Arr8 |    F9  Dep9  Arr9 |   F10 Dep10 Arr10 |   F11 Dep11 Arr11 |   F12 Dep12 Arr12 |   F13 Dep13 Arr13 |   F14 Dep14 Arr14 |   F15 Dep15 Arr15 |   F16 Dep16 Arr16 |   F17 Dep17 Arr17
#    1      -      -     - |     1    45   301 |     2   301   514 |     3   514   711 |     4   711   882 |     5   882  1116 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    2      -      -     - |     6    60   200 |     7   265   441 |     8   543   726 |    10   853  1133 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    3   1.00    177   626 |    11    60   349 |    12   349   471 |    14   695   895 |     9   895  1022 |    15  1022  1174 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    4      -      -     - |    13   471   695 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    5      -      -     - |    21    45   245 |    22   245   521 |    23   521   672 |    24   672   832 |    25   832  1099 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    6      -      -     - |    26   105   351 |    27   351   519 |    28   519   647 |    29   647   924 |    30   924  1142 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#
# Action: Flight 3, Aircraft 3
#
# Calculating reward for action: flight 3, aircraft 3
#   -24800.0 penalty for 496.0 minutes of additional delay (capped at 25000000)
#   -5000 penalty for 1 new cancelled flights: {11}
#   -0 penalty for inaction with remaining conflicts
#   +22.700000000000003 bonus for proactive action (454.0 minutes ahead)
#   -12.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -29889.3
# --------------------------------
# Action taken: Flight 3, Aircraft 3, Reward: -29889.3
#
# Step 2:
# action_mask: 126
# len action mask where value is 1: 85
# at current datetime: 2024-09-20 09:00:00
#
# State for:  proactive
# │ Current Time       │ Time Until End     │
# │         120        │         120        │
#
#   AC   Prob  Start   End |    F1  Dep1  Arr1 |    F2  Dep2  Arr2 |    F3  Dep3  Arr3 |    F4  Dep4  Arr4 |    F5  Dep5  Arr5 |    F6  Dep6  Arr6 |    F7  Dep7  Arr7 |    F8  Dep8  Arr8 |    F9  Dep9  Arr9 |   F10 Dep10 Arr10 |   F11 Dep11 Arr11 |   F12 Dep12 Arr12 |   F13 Dep13 Arr13 |   F14 Dep14 Arr14 |   F15 Dep15 Arr15 |   F16 Dep16 Arr16 |   F17 Dep17 Arr17
#    1      -      -     - |     1    45   301 |     2   301   514 |     4   711   882 |     5   882  1116 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    2      -      -     - |     6    60   200 |     7   265   441 |     8   543   726 |    10   853  1133 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    3   1.00    177   626 |    12   349   471 |     3   514   711 |    14   823  1023 |     9  1023  1150 |    15  1150  1302 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    4      -      -     - |    13   471   695 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    5      -      -     - |    21    45   245 |    22   245   521 |    23   521   672 |    24   672   832 |    25   832  1099 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    6      -      -     - |    26   105   351 |    27   351   519 |    28   519   647 |    29   647   924 |    30   924  1142 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#
# Action: Flight 4, Aircraft 6
#
# Calculating reward for action: flight 4, aircraft 6
#   -19200.0 penalty for 384.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +29.55 bonus for proactive action (591.0 minutes ahead)
#   -18.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -19288.4
# --------------------------------
# Action taken: Flight 4, Aircraft 6, Reward: -19288.4
#
# Step 3:
# action_mask: 126
# len action mask where value is 1: 85
# at current datetime: 2024-09-20 10:00:00
#
# State for:  proactive
# │ Current Time       │ Time Until End     │
# │         180        │         180        │
#
#   AC   Prob  Start   End |    F1  Dep1  Arr1 |    F2  Dep2  Arr2 |    F3  Dep3  Arr3 |    F4  Dep4  Arr4 |    F5  Dep5  Arr5 |    F6  Dep6  Arr6 |    F7  Dep7  Arr7 |    F8  Dep8  Arr8 |    F9  Dep9  Arr9 |   F10 Dep10 Arr10 |   F11 Dep11 Arr11 |   F12 Dep12 Arr12 |   F13 Dep13 Arr13 |   F14 Dep14 Arr14 |   F15 Dep15 Arr15 |   F16 Dep16 Arr16 |   F17 Dep17 Arr17
#    1      -      -     - |     1    45   301 |     2   301   514 |     5   882  1116 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    2      -      -     - |     6    60   200 |     7   265   441 |     8   543   726 |    10   853  1133 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    3   1.00    177   626 |    12   349   471 |     3   514   711 |    14   823  1023 |     9  1023  1150 |    15  1150  1302 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    4      -      -     - |    13   471   695 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    5      -      -     - |    21    45   245 |    22   245   521 |    23   521   672 |    24   672   832 |    25   832  1099 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    6      -      -     - |    26   105   351 |    27   351   519 |    28   519   647 |    29   647   924 |     4   924  1095 |    30  1095  1313 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#
# Action: Flight 13, Aircraft 0
#
# Calculating reward for action: flight 13, aircraft 0
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -5000 penalty for 1 new cancelled flights: {13}
#   -0 penalty for inaction with remaining conflicts
#   +14.55 bonus for proactive action (291.0 minutes ahead)
#   -24.0 penalty for time progression
# --------------------------------
# Total reward: -5009.4
# --------------------------------
# Action taken: Flight 13, Aircraft 0, Reward: -5009.4
#
# Step 4:
# action_mask: 126
# len action mask where value is 1: 78
# at current datetime: 2024-09-20 11:00:00
#
# State for:  proactive
# │ Current Time       │ Time Until End     │
# │         240        │         240        │
#
#   AC   Prob  Start   End |    F1  Dep1  Arr1 |    F2  Dep2  Arr2 |    F3  Dep3  Arr3 |    F4  Dep4  Arr4 |    F5  Dep5  Arr5 |    F6  Dep6  Arr6 |    F7  Dep7  Arr7 |    F8  Dep8  Arr8 |    F9  Dep9  Arr9 |   F10 Dep10 Arr10 |   F11 Dep11 Arr11 |   F12 Dep12 Arr12 |   F13 Dep13 Arr13 |   F14 Dep14 Arr14 |   F15 Dep15 Arr15 |   F16 Dep16 Arr16 |   F17 Dep17 Arr17
#    1      -      -     - |     1    45   301 |     2   301   514 |     5   882  1116 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    2      -      -     - |     6    60   200 |     7   265   441 |     8   543   726 |    10   853  1133 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    3   1.00    177   626 |    12   349   471 |     3   514   711 |    14   823  1023 |     9  1023  1150 |    15  1150  1302 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    4      -      -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    5      -      -     - |    21    45   245 |    22   245   521 |    23   521   672 |    24   672   832 |    25   832  1099 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    6      -      -     - |    26   105   351 |    27   351   519 |    28   519   647 |    29   647   924 |     4   924  1095 |    30  1095  1313 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#
# Action: Flight 12, Aircraft 4
#
# Calculating reward for action: flight 12, aircraft 4
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +5.45 bonus for proactive action (109.0 minutes ahead)
#   -30.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -124.6
# --------------------------------
# Action taken: Flight 12, Aircraft 4, Reward: -124.6
#
# Step 5:
# action_mask: 126
# len action mask where value is 1: 71
# at current datetime: 2024-09-20 12:00:00
#
# State for:  proactive
# │ Current Time       │ Time Until End     │
# │         300        │         300        │
#
#   AC   Prob  Start   End |    F1  Dep1  Arr1 |    F2  Dep2  Arr2 |    F3  Dep3  Arr3 |    F4  Dep4  Arr4 |    F5  Dep5  Arr5 |    F6  Dep6  Arr6 |    F7  Dep7  Arr7 |    F8  Dep8  Arr8 |    F9  Dep9  Arr9 |   F10 Dep10 Arr10 |   F11 Dep11 Arr11 |   F12 Dep12 Arr12 |   F13 Dep13 Arr13 |   F14 Dep14 Arr14 |   F15 Dep15 Arr15 |   F16 Dep16 Arr16 |   F17 Dep17 Arr17
#    1      -      -     - |     1    45   301 |     2   301   514 |     5   882  1116 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    2      -      -     - |     6    60   200 |     7   265   441 |     8   543   726 |    10   853  1133 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    3   1.00    177   626 |     3   514   711 |    14   823  1023 |     9  1023  1150 |    15  1150  1302 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    4      -      -     - |    12   349   471 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    5      -      -     - |    21    45   245 |    22   245   521 |    23   521   672 |    24   672   832 |    25   832  1099 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    6      -      -     - |    26   105   351 |    27   351   519 |    28   519   647 |    29   647   924 |     4   924  1095 |    30  1095  1313 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#
# Action: Flight 10, Aircraft 4
#
# Calculating reward for action: flight 10, aircraft 4
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +27.650000000000002 bonus for proactive action (553.0 minutes ahead)
#   -36.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -108.4
# --------------------------------
# Action taken: Flight 10, Aircraft 4, Reward: -108.4
#
# Step 6:
# action_mask: 126
# len action mask where value is 1: 57
# at current datetime: 2024-09-20 13:00:00
#
# State for:  proactive
# │ Current Time       │ Time Until End     │
# │         360        │         360        │
#
#   AC   Prob  Start   End |    F1  Dep1  Arr1 |    F2  Dep2  Arr2 |    F3  Dep3  Arr3 |    F4  Dep4  Arr4 |    F5  Dep5  Arr5 |    F6  Dep6  Arr6 |    F7  Dep7  Arr7 |    F8  Dep8  Arr8 |    F9  Dep9  Arr9 |   F10 Dep10 Arr10 |   F11 Dep11 Arr11 |   F12 Dep12 Arr12 |   F13 Dep13 Arr13 |   F14 Dep14 Arr14 |   F15 Dep15 Arr15 |   F16 Dep16 Arr16 |   F17 Dep17 Arr17
#    1      -      -     - |     1    45   301 |     2   301   514 |     5   882  1116 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    2      -      -     - |     6    60   200 |     7   265   441 |     8   543   726 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    3   1.00    177   626 |     3   514   711 |    14   823  1023 |     9  1023  1150 |    15  1150  1302 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    4      -      -     - |    12   349   471 |    10   853  1133 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    5      -      -     - |    21    45   245 |    22   245   521 |    23   521   672 |    24   672   832 |    25   832  1099 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    6      -      -     - |    26   105   351 |    27   351   519 |    28   519   647 |    29   647   924 |     4   924  1095 |    30  1095  1313 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#
# Action: Flight 15, Aircraft 1
#
# Calculating reward for action: flight 15, aircraft 1
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +39.5 bonus for proactive action (790.0 minutes ahead)
#   -42.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -102.5
# --------------------------------
# Action taken: Flight 15, Aircraft 1, Reward: -102.5
#
# Step 7:
# action_mask: 126
# len action mask where value is 1: 57
# at current datetime: 2024-09-20 14:00:00
#
# State for:  proactive
# │ Current Time       │ Time Until End     │
# │         420        │         420        │
#
#   AC   Prob  Start   End |    F1  Dep1  Arr1 |    F2  Dep2  Arr2 |    F3  Dep3  Arr3 |    F4  Dep4  Arr4 |    F5  Dep5  Arr5 |    F6  Dep6  Arr6 |    F7  Dep7  Arr7 |    F8  Dep8  Arr8 |    F9  Dep9  Arr9 |   F10 Dep10 Arr10 |   F11 Dep11 Arr11 |   F12 Dep12 Arr12 |   F13 Dep13 Arr13 |   F14 Dep14 Arr14 |   F15 Dep15 Arr15 |   F16 Dep16 Arr16 |   F17 Dep17 Arr17
#    1      -      -     - |     1    45   301 |     2   301   514 |     5   882  1116 |    15  1150  1302 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    2      -      -     - |     6    60   200 |     7   265   441 |     8   543   726 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    3   1.00    177   626 |     3   514   711 |    14   823  1023 |     9  1023  1150 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    4      -      -     - |    12   349   471 |    10   853  1133 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    5      -      -     - |    21    45   245 |    22   245   521 |    23   521   672 |    24   672   832 |    25   832  1099 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#    6      -      -     - |    26   105   351 |    27   351   519 |    28   519   647 |    29   647   924 |     4   924  1095 |    30  1095  1313 |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     - |     -     -     -
#
# Action: Flight 3, Aircraft 6
#
# Calculating reward for action: flight 3, aircraft 6
#   -39650.0 penalty for 793.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +4.7 bonus for proactive action (94.0 minutes ahead)
#   -48.0 penalty for time progression
#   +30000 final reward for resolving 1 real (non-cancelled) conflicts at scenario end: [12.0]
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -9793.3
# --------------------------------
# Action taken: Flight 3, Aircraft 6, Reward: -9793.3
# Total Reward: -79185.6
