# %%
import sys
sys.path.append("..")
import os
import numpy as np
from stable_baselines3 import DQN
from src.environment import AircraftDisruptionEnv
from scripts.visualizations import StatePlotter
from scripts.utils import load_scenario_data
from src.config import *
import re
import torch
import time
import ipywidgets as widgets
from IPython.display import display, clear_output, Image as IPImage
from io import BytesIO
import matplotlib.pyplot as plt
from datetime import timedelta

# Load the model and run inference
def run_inference_dqn(model_path, scenario_folder, env_type, seed, plot_title):
    # Load the scenario data
    data_dict = load_scenario_data(scenario_folder)

    # Extract necessary data for the environment
    aircraft_dict = data_dict['aircraft']
    flights_dict = data_dict['flights']
    rotations_dict = data_dict['rotations']
    alt_aircraft_dict = data_dict['alt_aircraft']
    config_dict = data_dict['config']

    # Initialize the environment
    env = AircraftDisruptionEnv(
        aircraft_dict, 
        flights_dict, 
        rotations_dict, 
        alt_aircraft_dict, 
        config_dict,
        env_type=env_type
    )

    # Load the trained model and set the environment
    model = DQN.load(model_path)
    model.set_env(env)

    # Set model to evaluation mode
    model.policy.set_training_mode(False)
    model.exploration_rate = 0.0

    # Set random seed for reproducibility
    np.random.seed(seed)
    torch.manual_seed(seed)

    print(f"seed: {seed}")

    # Create StatePlotter object for visualizing the environment state
    state_plotter = StatePlotter(
        aircraft_dict=env.aircraft_dict,
        flights_dict=env.flights_dict,
        rotations_dict=env.rotations_dict,
        alt_aircraft_dict=env.alt_aircraft_dict,
        start_datetime=env.start_datetime,
        end_datetime=env.end_datetime,
        uncertain_breakdowns=env.uncertain_breakdowns,
        plot_title=plot_title
    )

    # Reset the environment for inference
    obs, _ = env.reset()
    done_flag = False
    total_reward = 0
    step_num = 0
    max_steps = 1000  # Set a maximum number of steps to prevent infinite loops

    # List to collect images
    plots = []

    while not done_flag and step_num < max_steps:
        # Visualize the current state
        print(f"Step {step_num}:")

        # Extract necessary information from the environment for plotting
        swapped_flights = env.swapped_flights
        environment_delayed_flights = env.environment_delayed_flights
        current_datetime = env.current_datetime

        # Retrieve the updated dictionaries from the environment
        updated_flights_dict = env.flights_dict
        updated_rotations_dict = env.rotations_dict
        updated_alt_aircraft_dict = env.alt_aircraft_dict
        print("**updated_alt_aircraft_dict:")
        print(updated_alt_aircraft_dict)
        cancelled_flights = env.penalized_cancelled_flights

        if DEBUG_MODE_VISUALIZATION:
            print("Flights Dict:")
            print(updated_flights_dict)
            print("Alt Aircraft Dict:")
            print(updated_alt_aircraft_dict)
            print("Swapped Flights:")
            print(swapped_flights)
            print("Environment Delayed Flights:")
            print(environment_delayed_flights)
            print("Cancelled Flights:")
            print(cancelled_flights)
            print("Unavailabilities:")
            print(env.alt_aircraft_dict)
            print("Uncertain Breakdowns:")
            for key, value in env.uncertain_breakdowns.items():
                print(f"{key}: {value}")
            print("Current Breakdowns:")
            print(env.current_breakdowns)
            print("")

        # Update the StatePlotter's dictionaries with the updated ones
        state_plotter.alt_aircraft_dict = updated_alt_aircraft_dict
        state_plotter.flights_dict = updated_flights_dict
        state_plotter.rotations_dict = updated_rotations_dict

        if 'reward' not in locals():
            reward = 0
            action = 0
        
        # Collect the plot as an image
        fig = state_plotter.plot_state(
            updated_flights_dict, 
            swapped_flights, 
            environment_delayed_flights, 
            cancelled_flights, 
            current_datetime, 
            title_appendix=env_type,
            show_plot=False,
            reward_and_action=(reward, env.map_index_to_action(action), total_reward)
        )
        # Make figure taller
        # fig.set_figheight(10)
        # Convert the figure to an image buffer
        buf = BytesIO()
        fig.savefig(buf, format='png')
        buf.seek(0)
        img = IPImage(data=buf.read(), format='png', embed=True)
        plots.append(img)
        plt.close(fig)  # Close the figure to prevent automatic display

        # Get the action mask from the environment
        action_mask = obs['action_mask']

        # Convert observation to float32
        obs = {key: np.array(value, dtype=np.float32) for key, value in obs.items()}

        # Get the action mask from the observation
        action_mask = obs.get('action_mask', None)
        if action_mask is None:
            raise ValueError("Action mask is missing in the observation!")

        # Get the Q-values and apply the action mask
        obs_tensor = model.policy.obs_to_tensor(obs)[0]
        q_values = model.policy.q_net(obs_tensor).detach().cpu().numpy().squeeze()

        # Mask invalid actions by setting their Q-values to -inf
        masked_q_values = q_values.copy()
        masked_q_values[action_mask == 0] = -np.inf

        if env_type == 'reactive':
            print(f"*** amount of allowed actions: {np.sum(action_mask)}")
        # Predict the action using the masked Q-values
        action = np.argmax(masked_q_values)

        # Verify if the action is valid
        if action_mask[action] == 0:
            raise ValueError(f"Invalid action selected by the model: {action}")

        # Take action in the environment
        obs, reward, terminated, truncated, info = env.step(action)

        # Accumulate the reward
        total_reward += reward

        action_mapped = env.map_index_to_action(action)
        print("action index:")
        print(action)
        print("action mapped:")
        print(action_mapped)
        print(f"Action taken: {action_mapped}, Reward: {reward}")

        # Combine terminated and truncated flags
        done_flag = terminated or truncated

        step_num += 1

    print("================================================")
    print("Final state:")

    current_datetime += timedelta(hours=TIMESTEP_HOURS)

    # Plot the final state and collect it
    fig = state_plotter.plot_state(
        updated_flights_dict, 
        swapped_flights, 
        environment_delayed_flights, 
        cancelled_flights, 
        current_datetime, 
        title_appendix=env_type,
        show_plot=False,
        reward_and_action=(reward, env.map_index_to_action(action), total_reward)
    )
    # Make figure taller
    # fig.set_figheight(12)
    # Convert the figure to an image buffer
    buf = BytesIO()
    fig.savefig(buf, format='png')
    buf.seek(0)
    img = IPImage(data=buf.read(), format='png', embed=True)
    plots.append(img)
    plt.close(fig)  # Close the figure to prevent automatic display

    print(f"Total Reward: {total_reward}")
    print(f"Total Steps: {step_num}")

    # Create an interactive slider to display the plots
    def update_plot(index):
        with output:
            clear_output(wait=True)
            display(plots[index])

    slider = widgets.IntSlider(
        value=0, min=0, max=len(plots)-1, step=1, description='Step:'
    )
    output = widgets.Output()

    slider.observe(lambda change: update_plot(change['new']), names='value')

    # Create buttons for navigation
    prev_button = widgets.Button(description='⬅️', layout=widgets.Layout(width='40px'))
    next_button = widgets.Button(description='➡️', layout=widgets.Layout(width='40px'))
    
    def on_prev_button_clicked(b):
        slider.value = max(0, slider.value - 1)
    
    def on_next_button_clicked(b):
        slider.value = min(len(plots)-1, slider.value + 1)
    
    prev_button.on_click(on_prev_button_clicked)
    next_button.on_click(on_next_button_clicked)
    
    # Create a horizontal box to hold the navigation controls
    navigation = widgets.HBox([prev_button, next_button, slider])
    
    # Display the initial plot
    update_plot(0)
    
    # Display the navigation controls and output
    display(navigation, output)

    return total_reward, step_num


seed = 42

SCENARIO_FOLDER = "../../data/Testing/6ac-700-diverse/deterministic_na_Scenario_009"

models = [

    ("../../trained_models/dqn/6ac-700-diverse/1025/myopic-91.zip", "myopic", "DQN Proactive-N"),
    ("../../trained_models/dqn/6ac-700-diverse/1025/proactive-94.zip", "proactive", "DQN Proactive-U"), 
    ("../../trained_models/dqn/6ac-700-diverse/1025/reactive-97.zip", "reactive", "DQN Reactive"),
]


for model in models:
    MODEL_PATH = model[0]
    env_type = model[1]
    plot_title = model[2]
    print("*****"*10)
    print(f"Model Path: {MODEL_PATH}")
    print(f"Environment Type: {env_type}")
    if not os.path.exists(SCENARIO_FOLDER):
        raise FileNotFoundError(f"Scenario folder not found: {SCENARIO_FOLDER}")

    if not os.path.exists(MODEL_PATH):
        raise FileNotFoundError(f"Model file not found: {MODEL_PATH}")

    # Run the fixed inference loop
    run_inference_dqn(MODEL_PATH, SCENARIO_FOLDER, env_type, seed, plot_title)
# Out:
# **************************************************
# Model Path: ../../trained_models/dqn/6ac-700-diverse/1025/myopic-91.zip
# Environment Type: myopic
# seed: 42
# Step 0:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 6, aircraft 6
#   -56250.0 penalty for 1125.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +21.1 bonus for proactive action (422.0 minutes ahead)
#   -6.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -56334.9
# --------------------------------
# action index:
# 48
# action mapped:
# (6, 6)
# Action taken: (6, 6), Reward: -56334.9
# Step 1:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 19, aircraft 2
#   -7850.0 penalty for 157.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +8.25 bonus for proactive action (165.0 minutes ahead)
#   -12.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -7953.8
# --------------------------------
# action index:
# 135
# action mapped:
# (19, 2)
# Action taken: (19, 2), Reward: -7953.8
# Step 2:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 10, aircraft 1
#   -9400.0 penalty for 188.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +9.450000000000001 bonus for proactive action (189.0 minutes ahead)
#   -18.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -9508.6
# --------------------------------
# action index:
# 71
# action mapped:
# (10, 1)
# Action taken: (10, 1), Reward: -9508.6
# Step 3:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 10, aircraft 1
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -24.0 penalty for time progression
# --------------------------------
# Total reward: -24.0
# --------------------------------
# action index:
# 71
# action mapped:
# (10, 1)
# Action taken: (10, 1), Reward: -24.0
# Step 4:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 4, aircraft 1
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -30.0 penalty for time progression
# --------------------------------
# Total reward: -30.0
# --------------------------------
# action index:
# 29
# action mapped:
# (4, 1)
# Action taken: (4, 1), Reward: -30.0
# Step 5:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 4, aircraft 1
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -36.0 penalty for time progression
# --------------------------------
# Total reward: -36.0
# --------------------------------
# action index:
# 29
# action mapped:
# (4, 1)
# Action taken: (4, 1), Reward: -36.0
# Step 6:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 4, aircraft 1
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -42.0 penalty for time progression
# --------------------------------
# Total reward: -42.0
# --------------------------------
# action index:
# 29
# action mapped:
# (4, 1)
# Action taken: (4, 1), Reward: -42.0
# Step 7:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 4, aircraft 1
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -48.0 penalty for time progression
# --------------------------------
# Total reward: -48.0
# --------------------------------
# action index:
# 29
# action mapped:
# (4, 1)
# Action taken: (4, 1), Reward: -48.0
# Step 8:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 4, aircraft 1
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -5000 penalty for 1 new cancelled flights: {20}
#   -0 penalty for inaction with remaining conflicts
#   -54.0 penalty for time progression
# --------------------------------
# Total reward: -5054.0
# --------------------------------
# action index:
# 29
# action mapped:
# (4, 1)
# Action taken: (4, 1), Reward: -5054.0
# Step 9:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 4, aircraft 1
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -60.0 penalty for time progression
# --------------------------------
# Total reward: -60.0
# --------------------------------
# action index:
# 29
# action mapped:
# (4, 1)
# Action taken: (4, 1), Reward: -60.0
# Step 10:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 4, aircraft 1
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -66.0 penalty for time progression
# --------------------------------
# Total reward: -66.0
# --------------------------------
# action index:
# 29
# action mapped:
# (4, 1)
# Action taken: (4, 1), Reward: -66.0
# Step 11:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 4, aircraft 1
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -72.0 penalty for time progression
# --------------------------------
# Total reward: -72.0
# --------------------------------
# action index:
# 29
# action mapped:
# (4, 1)
# Action taken: (4, 1), Reward: -72.0
# Step 12:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 4, aircraft 1
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -78.0 penalty for time progression
# --------------------------------
# Total reward: -78.0
# --------------------------------
# action index:
# 29
# action mapped:
# (4, 1)
# Action taken: (4, 1), Reward: -78.0
# Step 13:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 12, aircraft 3
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -84.0 penalty for time progression
# --------------------------------
# Total reward: -84.0
# --------------------------------
# action index:
# 87
# action mapped:
# (12, 3)
# Action taken: (12, 3), Reward: -84.0
# Step 14:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 0, aircraft 0
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -5000 penalty for 1 new cancelled flights: {21}
#   -0 penalty for inaction with remaining conflicts
#   -90.0 penalty for time progression
#   +30000 final reward for resolving 1 real (non-cancelled) conflicts at scenario end: [19.0]
# --------------------------------
# Total reward: 24910.0
# --------------------------------
# action index:
# 0
# action mapped:
# (0, 0)
# Action taken: (0, 0), Reward: 24910.0
# ================================================
# Final state:
# Total Reward: -54481.3
# Total Steps: 15
# HBox(children=(Button(description='⬅️', layout=Layout(width='40px'), style=ButtonStyle()), Button(description=…
# Output()
# **************************************************
# Model Path: ../../trained_models/dqn/6ac-700-diverse/1025/proactive-94.zip
# Environment Type: proactive
# seed: 42
# Step 0:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 1, aircraft 5
#   -37250.0 penalty for 745.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +3.75 bonus for proactive action (75.0 minutes ahead)
#   -6.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -37352.2
# --------------------------------
# action index:
# 12
# action mapped:
# (1, 5)
# Action taken: (1, 5), Reward: -37352.2
# Step 1:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 11, aircraft 5
#   -10350.0 penalty for 207.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +21.650000000000002 bonus for proactive action (433.0 minutes ahead)
#   -12.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -10440.4
# --------------------------------
# action index:
# 82
# action mapped:
# (11, 5)
# Action taken: (11, 5), Reward: -10440.4
# Step 2:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 7, aircraft 2
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -18.0 penalty for time progression
# --------------------------------
# Total reward: -18.0
# --------------------------------
# action index:
# 51
# action mapped:
# (7, 2)
# Action taken: (7, 2), Reward: -18.0
# Step 3:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 6, aircraft 2
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -5000 penalty for 1 new cancelled flights: {19}
#   -0 penalty for inaction with remaining conflicts
#   -24.0 penalty for time progression
# --------------------------------
# Total reward: -5024.0
# --------------------------------
# action index:
# 44
# action mapped:
# (6, 2)
# Action taken: (6, 2), Reward: -5024.0
# Step 4:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 10, aircraft 3
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -30.0 penalty for time progression
# --------------------------------
# Total reward: -30.0
# --------------------------------
# action index:
# 73
# action mapped:
# (10, 3)
# Action taken: (10, 3), Reward: -30.0
# Step 5:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 10, aircraft 3
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -36.0 penalty for time progression
# --------------------------------
# Total reward: -36.0
# --------------------------------
# action index:
# 73
# action mapped:
# (10, 3)
# Action taken: (10, 3), Reward: -36.0
# Step 6:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 20, aircraft 4
#   -9100.0 penalty for 182.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +7.45 bonus for proactive action (149.0 minutes ahead)
#   -42.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -9234.6
# --------------------------------
# action index:
# 144
# action mapped:
# (20, 4)
# Action taken: (20, 4), Reward: -9234.6
# Step 7:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 6, aircraft 6
#   -56250.0 penalty for 1125.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +0.1 bonus for proactive action (2.0 minutes ahead)
#   -48.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -56397.9
# --------------------------------
# action index:
# 48
# action mapped:
# (6, 6)
# Action taken: (6, 6), Reward: -56397.9
# Step 8:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 11, aircraft 5
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +11.0 bonus for proactive action (220.0 minutes ahead)
#   -54.0 penalty for time progression
# --------------------------------
# Total reward: -43.0
# --------------------------------
# action index:
# 82
# action mapped:
# (11, 5)
# Action taken: (11, 5), Reward: -43.0
# Step 9:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 4, aircraft 4
#   -1200.0 penalty for 24.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +6.3500000000000005 bonus for proactive action (127.0 minutes ahead)
#   -60.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -1353.6
# --------------------------------
# action index:
# 32
# action mapped:
# (4, 4)
# Action taken: (4, 4), Reward: -1353.6
# Step 10:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 4, aircraft 5
#   -450.0 penalty for 9.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +4.55 bonus for proactive action (91.0 minutes ahead)
#   -66.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -611.4
# --------------------------------
# action index:
# 33
# action mapped:
# (4, 5)
# Action taken: (4, 5), Reward: -611.4
# Step 11:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 4, aircraft 5
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +2.0 bonus for proactive action (40.0 minutes ahead)
#   -72.0 penalty for time progression
# --------------------------------
# Total reward: -70.0
# --------------------------------
# action index:
# 33
# action mapped:
# (4, 5)
# Action taken: (4, 5), Reward: -70.0
# Step 12:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 20, aircraft 4
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -78.0 penalty for time progression
# --------------------------------
# Total reward: -78.0
# --------------------------------
# action index:
# 144
# action mapped:
# (20, 4)
# Action taken: (20, 4), Reward: -78.0
# Step 13:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 20, aircraft 4
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -84.0 penalty for time progression
# --------------------------------
# Total reward: -84.0
# --------------------------------
# action index:
# 144
# action mapped:
# (20, 4)
# Action taken: (20, 4), Reward: -84.0
# Step 14:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
#
# Calculating reward for action: flight 20, aircraft 4
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -5000 penalty for 1 new cancelled flights: {21}
#   -0 penalty for inaction with remaining conflicts
#   -90.0 penalty for time progression
#   +30000 final reward for resolving 1 real (non-cancelled) conflicts at scenario end: [20.0]
# --------------------------------
# Total reward: 24910.0
# --------------------------------
# action index:
# 144
# action mapped:
# (20, 4)
# Action taken: (20, 4), Reward: 24910.0
# ================================================
# Final state:
# Total Reward: -95863.1
# Total Steps: 15
# HBox(children=(Button(description='⬅️', layout=Layout(width='40px'), style=ButtonStyle()), Button(description=…
# Output()
# **************************************************
# Model Path: ../../trained_models/dqn/6ac-700-diverse/1025/reactive-97.zip
# Environment Type: reactive
# seed: 42
# Step 0:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 1.0
#
# Calculating reward for action: flight 0, aircraft 0
#   -0 penalty for 0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0.2 penalty for inaction with remaining conflicts
#   -6.0 penalty for time progression
# --------------------------------
# Total reward: -6.2
# --------------------------------
# action index:
# 0
# action mapped:
# (0, 0)
# Action taken: (0, 0), Reward: -6.2
# Step 1:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 1.0
#
# Calculating reward for action: flight 0, aircraft 0
#   -0 penalty for 0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0.2 penalty for inaction with remaining conflicts
#   -12.0 penalty for time progression
# --------------------------------
# Total reward: -12.2
# --------------------------------
# action index:
# 0
# action mapped:
# (0, 0)
# Action taken: (0, 0), Reward: -12.2
# Step 2:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 1.0
#
# Calculating reward for action: flight 0, aircraft 0
#   -0 penalty for 0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0.2 penalty for inaction with remaining conflicts
#   -18.0 penalty for time progression
# --------------------------------
# Total reward: -18.2
# --------------------------------
# action index:
# 0
# action mapped:
# (0, 0)
# Action taken: (0, 0), Reward: -18.2
# Step 3:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 99.0
#
# Calculating reward for action: flight 20, aircraft 4
#   -9100.0 penalty for 182.0 minutes of additional delay (capped at 25000000)
#   -5000 penalty for 1 new cancelled flights: {19}
#   -0 penalty for inaction with remaining conflicts
#   +16.45 bonus for proactive action (329.0 minutes ahead)
#   -24.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -14207.6
# --------------------------------
# action index:
# 144
# action mapped:
# (20, 4)
# Action taken: (20, 4), Reward: -14207.6
# Step 4:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 85.0
#
# Calculating reward for action: flight 2, aircraft 4
#   -5250.0 penalty for 105.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +2.9000000000000004 bonus for proactive action (58.0 minutes ahead)
#   -30.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -5377.1
# --------------------------------
# action index:
# 18
# action mapped:
# (2, 4)
# Action taken: (2, 4), Reward: -5377.1
# Step 5:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 85.0
#
# Calculating reward for action: flight 15, aircraft 5
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +43.1 bonus for proactive action (862.0 minutes ahead)
#   -36.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -92.9
# --------------------------------
# action index:
# 110
# action mapped:
# (15, 5)
# Action taken: (15, 5), Reward: -92.9
# Step 6:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 78.0
#
# Calculating reward for action: flight 20, aircraft 4
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -42.0 penalty for time progression
# --------------------------------
# Total reward: -42.0
# --------------------------------
# action index:
# 144
# action mapped:
# (20, 4)
# Action taken: (20, 4), Reward: -42.0
# Step 7:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 71.0
#
# Calculating reward for action: flight 20, aircraft 4
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -48.0 penalty for time progression
# --------------------------------
# Total reward: -48.0
# --------------------------------
# action index:
# 144
# action mapped:
# (20, 4)
# Action taken: (20, 4), Reward: -48.0
# Step 8:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 64.0
#
# Calculating reward for action: flight 20, aircraft 4
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -54.0 penalty for time progression
# --------------------------------
# Total reward: -54.0
# --------------------------------
# action index:
# 144
# action mapped:
# (20, 4)
# Action taken: (20, 4), Reward: -54.0
# Step 9:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 50.0
#
# Calculating reward for action: flight 20, aircraft 4
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -60.0 penalty for time progression
# --------------------------------
# Total reward: -60.0
# --------------------------------
# action index:
# 144
# action mapped:
# (20, 4)
# Action taken: (20, 4), Reward: -60.0
# Step 10:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 43.0
#
# Calculating reward for action: flight 20, aircraft 4
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -66.0 penalty for time progression
# --------------------------------
# Total reward: -66.0
# --------------------------------
# action index:
# 144
# action mapped:
# (20, 4)
# Action taken: (20, 4), Reward: -66.0
# Step 11:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 36.0
#
# Calculating reward for action: flight 20, aircraft 4
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -72.0 penalty for time progression
# --------------------------------
# Total reward: -72.0
# --------------------------------
# action index:
# 144
# action mapped:
# (20, 4)
# Action taken: (20, 4), Reward: -72.0
# Step 12:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 29.0
#
# Calculating reward for action: flight 20, aircraft 4
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -78.0 penalty for time progression
# --------------------------------
# Total reward: -78.0
# --------------------------------
# action index:
# 144
# action mapped:
# (20, 4)
# Action taken: (20, 4), Reward: -78.0
# Step 13:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 22.0
#
# Calculating reward for action: flight 20, aircraft 4
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -84.0 penalty for time progression
# --------------------------------
# Total reward: -84.0
# --------------------------------
# action index:
# 144
# action mapped:
# (20, 4)
# Action taken: (20, 4), Reward: -84.0
# Step 14:
# **updated_alt_aircraft_dict:
# {'B737#6': {'StartDate': '28/09/24', 'StartTime': '12:44', 'EndDate': '28/09/24', 'EndTime': '20:38', 'Probability': 1.0}, 'B737#5': {'StartDate': '28/09/24', 'StartTime': '09:54', 'EndDate': '28/09/24', 'EndTime': '11:58', 'Probability': 1.0}}
# *** amount of allowed actions: 15.0
#
# Calculating reward for action: flight 20, aircraft 4
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -5000 penalty for 1 new cancelled flights: {21}
#   -0 penalty for inaction with remaining conflicts
#   -90.0 penalty for time progression
#   +30000 final reward for resolving 1 real (non-cancelled) conflicts at scenario end: [20.0]
# --------------------------------
# Total reward: 24910.0
# --------------------------------
# action index:
# 144
# action mapped:
# (20, 4)
# Action taken: (20, 4), Reward: 24910.0
# ================================================
# Final state:
# Total Reward: 4691.799999999996
# Total Steps: 15
# HBox(children=(Button(description='⬅️', layout=Layout(width='40px'), style=ButtonStyle()), Button(description=…
# Output()
