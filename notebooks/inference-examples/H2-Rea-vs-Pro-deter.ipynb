# %%
import sys
sys.path.append("..")
import os
import numpy as np
from stable_baselines3 import DQN
from src.environment import AircraftDisruptionEnv
from scripts.visualizations import StatePlotter
from scripts.utils import load_scenario_data
from src.config import *
import re
import torch
import time
import ipywidgets as widgets
from IPython.display import display, clear_output, Image as IPImage
from io import BytesIO
import matplotlib.pyplot as plt
from datetime import timedelta

# Load the model and run inference
def run_inference_dqn(model_path, scenario_folder, env_type, seed, plot_title):
    # Load the scenario data
    data_dict = load_scenario_data(scenario_folder)

    # Extract necessary data for the environment
    aircraft_dict = data_dict['aircraft']
    flights_dict = data_dict['flights']
    rotations_dict = data_dict['rotations']
    alt_aircraft_dict = data_dict['alt_aircraft']
    config_dict = data_dict['config']

    # Initialize the environment
    env = AircraftDisruptionEnv(
        aircraft_dict, 
        flights_dict, 
        rotations_dict, 
        alt_aircraft_dict, 
        config_dict,
        env_type=env_type
    )

    # Load the trained model and set the environment
    model = DQN.load(model_path)
    model.set_env(env)

    # Set model to evaluation mode
    model.policy.set_training_mode(False)
    model.exploration_rate = 0.0

    # Set random seed for reproducibility
    np.random.seed(seed)
    torch.manual_seed(seed)

    print(f"seed: {seed}")

    # Create StatePlotter object for visualizing the environment state
    state_plotter = StatePlotter(
        aircraft_dict=env.aircraft_dict,
        flights_dict=env.flights_dict,
        rotations_dict=env.rotations_dict,
        alt_aircraft_dict=env.alt_aircraft_dict,
        start_datetime=env.start_datetime,
        end_datetime=env.end_datetime,
        uncertain_breakdowns=env.uncertain_breakdowns,
        plot_title=plot_title
    )

    # Reset the environment for inference
    obs, _ = env.reset()
    done_flag = False
    total_reward = 0
    step_num = 0
    max_steps = 1000  # Set a maximum number of steps to prevent infinite loops

    # List to collect images
    plots = []

    while not done_flag and step_num < max_steps:
        # Visualize the current state
        print(f"Step {step_num}:")

        # Extract necessary information from the environment for plotting
        swapped_flights = env.swapped_flights
        environment_delayed_flights = env.environment_delayed_flights
        current_datetime = env.current_datetime

        # Retrieve the updated dictionaries from the environment
        updated_flights_dict = env.flights_dict
        updated_rotations_dict = env.rotations_dict
        updated_alt_aircraft_dict = env.alt_aircraft_dict
        print("**updated_alt_aircraft_dict:")
        print(updated_alt_aircraft_dict)
        cancelled_flights = env.penalized_cancelled_flights

        if DEBUG_MODE_VISUALIZATION:
            print("Flights Dict:")
            print(updated_flights_dict)
            print("Alt Aircraft Dict:")
            print(updated_alt_aircraft_dict)
            print("Swapped Flights:")
            print(swapped_flights)
            print("Environment Delayed Flights:")
            print(environment_delayed_flights)
            print("Cancelled Flights:")
            print(cancelled_flights)
            print("Unavailabilities:")
            print(env.alt_aircraft_dict)
            print("Uncertain Breakdowns:")
            for key, value in env.uncertain_breakdowns.items():
                print(f"{key}: {value}")
            print("Current Breakdowns:")
            print(env.current_breakdowns)
            print("")

        # Update the StatePlotter's dictionaries with the updated ones
        state_plotter.alt_aircraft_dict = updated_alt_aircraft_dict
        state_plotter.flights_dict = updated_flights_dict
        state_plotter.rotations_dict = updated_rotations_dict

        if 'reward' not in locals():
            reward = 0
            action = 0
        
        # Collect the plot as an image
        fig = state_plotter.plot_state(
            updated_flights_dict, 
            swapped_flights, 
            environment_delayed_flights, 
            cancelled_flights, 
            current_datetime, 
            title_appendix=env_type,
            show_plot=False,
            reward_and_action=(reward, env.map_index_to_action(action), total_reward)
        )

        save_folder = f"H2-Rea-vs-Pro-deter/{env_type}"
        
        # Save plot to png folder with step number
        os.makedirs(f"png/{save_folder}", exist_ok=True)
        fig.savefig(f"png/{save_folder}/step_{step_num}.png")
        # Make figure taller
        # fig.set_figheight(10)
        # Convert the figure to an image buffer
        buf = BytesIO()
        fig.savefig(buf, format='png')
        buf.seek(0)
        img = IPImage(data=buf.read(), format='png', embed=True)
        plots.append(img)
        plt.close(fig)  # Close the figure to prevent automatic display

        # Get the action mask from the environment
        action_mask = obs['action_mask']

        # Convert observation to float32
        obs = {key: np.array(value, dtype=np.float32) for key, value in obs.items()}

        # Get the action mask from the observation
        action_mask = obs.get('action_mask', None)
        if action_mask is None:
            raise ValueError("Action mask is missing in the observation!")

        # Get the Q-values and apply the action mask
        obs_tensor = model.policy.obs_to_tensor(obs)[0]
        q_values = model.policy.q_net(obs_tensor).detach().cpu().numpy().squeeze()

        # Mask invalid actions by setting their Q-values to -inf
        masked_q_values = q_values.copy()
        masked_q_values[action_mask == 0] = -np.inf

        if env_type == 'reactive':
            print(f"*** amount of allowed actions: {np.sum(action_mask)}")
        # Predict the action using the masked Q-values
        action = np.argmax(masked_q_values)

        # Verify if the action is valid
        if action_mask[action] == 0:
            raise ValueError(f"Invalid action selected by the model: {action}")

        # Take action in the environment
        obs, reward, terminated, truncated, info = env.step(action)

        # Accumulate the reward
        total_reward += reward

        action_mapped = env.map_index_to_action(action)
        print("action index:")
        print(action)
        print("action mapped:")
        print(action_mapped)
        print(f"Action taken: {action_mapped}, Reward: {reward}")

        # Combine terminated and truncated flags
        done_flag = terminated or truncated

        step_num += 1

    print("================================================")
    print("Final state:")

    current_datetime += timedelta(hours=TIMESTEP_HOURS)

    # Plot the final state and collect it
    fig = state_plotter.plot_state(
        updated_flights_dict, 
        swapped_flights, 
        environment_delayed_flights, 
        cancelled_flights, 
        current_datetime, 
        title_appendix=env_type,
        show_plot=False,
        reward_and_action=(reward, env.map_index_to_action(action), total_reward)
    )

    save_folder = f"H2-Rea-vs-Pro-deter/{env_type}"
    
    # Save plot to png folder with step number
    os.makedirs(f"png/{save_folder}", exist_ok=True)
    fig.savefig(f"png/{save_folder}/step_{step_num}.png")
    # Make figure taller
    # fig.set_figheight(12)
    # Convert the figure to an image buffer
    buf = BytesIO()
    fig.savefig(buf, format='png')
    buf.seek(0)
    img = IPImage(data=buf.read(), format='png', embed=True)
    plots.append(img)
    plt.close(fig)  # Close the figure to prevent automatic display

    print(f"Total Reward: {total_reward}")
    print(f"Total Steps: {step_num}")

    # Create an interactive slider to display the plots
    def update_plot(index):
        with output:
            clear_output(wait=True)
            display(plots[index])

    slider = widgets.IntSlider(
        value=0, min=0, max=len(plots)-1, step=1, description='Step:'
    )
    output = widgets.Output()

    slider.observe(lambda change: update_plot(change['new']), names='value')

    # Create buttons for navigation
    prev_button = widgets.Button(description='⬅️', layout=widgets.Layout(width='40px'))
    next_button = widgets.Button(description='➡️', layout=widgets.Layout(width='40px'))
    
    def on_prev_button_clicked(b):
        slider.value = max(0, slider.value - 1)
    
    def on_next_button_clicked(b):
        slider.value = min(len(plots)-1, slider.value + 1)
    
    prev_button.on_click(on_prev_button_clicked)
    next_button.on_click(on_next_button_clicked)
    
    # Create a horizontal box to hold the navigation controls
    navigation = widgets.HBox([prev_button, next_button, slider])
    
    # Display the initial plot
    update_plot(0)
    
    # Display the navigation controls and output
    display(navigation, output)

    return total_reward, step_num


seed = 42

SCENARIO_FOLDER = "../../data/Testing/6ac-700-diverse/mixed_medium_Scenario_061"

models = [

    # ("../../trained_models/dqn/6ac-700-diverse/1025/myopic-91.zip", "myopic", "DQN Proactive-N"),
    ("../../trained_models/dqn/6ac-700-diverse/1025/proactive-94.zip", "proactive", "DQN Proactive-U"), 
    ("../../trained_models/dqn/6ac-700-diverse/1025/reactive-97.zip", "reactive", "DQN Reactive"),
]


for model in models:
    MODEL_PATH = model[0]
    env_type = model[1]
    plot_title = model[2]
    print("*****"*10)
    print(f"Model Path: {MODEL_PATH}")
    print(f"Environment Type: {env_type}")
    if not os.path.exists(SCENARIO_FOLDER):
        raise FileNotFoundError(f"Scenario folder not found: {SCENARIO_FOLDER}")

    if not os.path.exists(MODEL_PATH):
        raise FileNotFoundError(f"Model file not found: {MODEL_PATH}")

    # Run the fixed inference loop
    run_inference_dqn(MODEL_PATH, SCENARIO_FOLDER, env_type, seed, plot_title)
# Out:
# **************************************************
# Model Path: ../../trained_models/dqn/6ac-700-diverse/1025/proactive-94.zip
# Environment Type: proactive
# seed: 42
# Step 0:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.66}}
#
# Calculating reward for action: flight 12, aircraft 2
#   -1800.0 penalty for 36.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +25.05 bonus for proactive action (501.0 minutes ahead)
#   -6.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -1881.0
# --------------------------------
# action index:
# 86
# action mapped:
# (12, 2)
# Action taken: (12, 2), Reward: -1881.0
# Step 1:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.6734701476785817}}
#
# Calculating reward for action: flight 12, aircraft 2
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -12.0 penalty for time progression
# --------------------------------
# Total reward: -12.0
# --------------------------------
# action index:
# 86
# action mapped:
# (12, 2)
# Action taken: (12, 2), Reward: -12.0
# Step 2:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.6944511554921714}}
#
# Calculating reward for action: flight 13, aircraft 2
#   -50.0 penalty for 1.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +27.900000000000002 bonus for proactive action (558.0 minutes ahead)
#   -18.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -140.1
# --------------------------------
# action index:
# 93
# action mapped:
# (13, 2)
# Action taken: (13, 2), Reward: -140.1
# Step 3:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.751258139709112}}
#
# Calculating reward for action: flight 8, aircraft 3
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -5000 penalty for 1 new cancelled flights: {11}
#   -0 penalty for inaction with remaining conflicts
#   -24.0 penalty for time progression
# --------------------------------
# Total reward: -5024.0
# --------------------------------
# action index:
# 59
# action mapped:
# (8, 3)
# Action taken: (8, 3), Reward: -5024.0
# Step 4:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.7575633812374329}}
#
# Calculating reward for action: flight 10, aircraft 1
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   +15.65 bonus for proactive action (313.0 minutes ahead)
#   -30.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -114.4
# --------------------------------
# action index:
# 71
# action mapped:
# (10, 1)
# Action taken: (10, 1), Reward: -114.4
# Step 5:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.7197906061230468}}
#
# Calculating reward for action: flight 17, aircraft 5
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -36.0 penalty for time progression
# --------------------------------
# Total reward: -36.0
# --------------------------------
# action index:
# 124
# action mapped:
# (17, 5)
# Action taken: (17, 5), Reward: -36.0
# Step 6:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.7751413011385907}}
#
# Calculating reward for action: flight 17, aircraft 5
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -42.0 penalty for time progression
# --------------------------------
# Total reward: -42.0
# --------------------------------
# action index:
# 124
# action mapped:
# (17, 5)
# Action taken: (17, 5), Reward: -42.0
# Step 7:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.7915584377287884}}
#
# Calculating reward for action: flight 17, aircraft 5
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0 penalty for inaction with remaining conflicts
#   -48.0 penalty for time progression
#   +90000 final reward for resolving 3 real (non-cancelled) conflicts at scenario end: [10.0, 13.0, 12.0]
# --------------------------------
# Total reward: 89952.0
# --------------------------------
# action index:
# 124
# action mapped:
# (17, 5)
# Action taken: (17, 5), Reward: 89952.0
# ================================================
# Final state:
# Total Reward: 82702.5
# Total Steps: 8
# HBox(children=(Button(description='⬅️', layout=Layout(width='40px'), style=ButtonStyle()), Button(description=…
# Output()
# **************************************************
# Model Path: ../../trained_models/dqn/6ac-700-diverse/1025/reactive-97.zip
# Environment Type: reactive
# seed: 42
# Step 0:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.66}}
# *** amount of allowed actions: 1.0
#
# Calculating reward for action: flight 0, aircraft 0
#   -0 penalty for 0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0.2 penalty for inaction with remaining conflicts
#   -6.0 penalty for time progression
# --------------------------------
# Total reward: -6.2
# --------------------------------
# action index:
# 0
# action mapped:
# (0, 0)
# Action taken: (0, 0), Reward: -6.2
# Step 1:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.6640397387960829}}
# *** amount of allowed actions: 1.0
#
# Calculating reward for action: flight 0, aircraft 0
#   -0 penalty for 0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0.2 penalty for inaction with remaining conflicts
#   -12.0 penalty for time progression
# --------------------------------
# Total reward: -12.2
# --------------------------------
# action index:
# 0
# action mapped:
# (0, 0)
# Action taken: (0, 0), Reward: -12.2
# Step 2:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.7043267177964717}}
# *** amount of allowed actions: 120.0
#
# Calculating reward for action: flight 0, aircraft 0
#   -0 penalty for 0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0.2 penalty for inaction with remaining conflicts
#   -18.0 penalty for time progression
# --------------------------------
# Total reward: -18.2
# --------------------------------
# action index:
# 0
# action mapped:
# (0, 0)
# Action taken: (0, 0), Reward: -18.2
# Step 3:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.7490624069699583}}
# *** amount of allowed actions: 106.0
#
# Calculating reward for action: flight 15, aircraft 3
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -5000 penalty for 1 new cancelled flights: {11}
#   -0 penalty for inaction with remaining conflicts
#   +10.200000000000001 bonus for proactive action (204.0 minutes ahead)
#   -24.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -5113.8
# --------------------------------
# action index:
# 108
# action mapped:
# (15, 3)
# Action taken: (15, 3), Reward: -5113.8
# Step 4:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.7986435445176719}}
# *** amount of allowed actions: 1.0
#
# Calculating reward for action: flight 0, aircraft 0
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0.2 penalty for inaction with remaining conflicts
#   -30.0 penalty for time progression
# --------------------------------
# Total reward: -30.2
# --------------------------------
# action index:
# 0
# action mapped:
# (0, 0)
# Action taken: (0, 0), Reward: -30.2
# Step 5:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.8521368036815407}}
# *** amount of allowed actions: 1.0
#
# Calculating reward for action: flight 0, aircraft 0
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0.2 penalty for inaction with remaining conflicts
#   -36.0 penalty for time progression
# --------------------------------
# Total reward: -36.2
# --------------------------------
# action index:
# 0
# action mapped:
# (0, 0)
# Action taken: (0, 0), Reward: -36.2
# Step 6:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.8848296691719274}}
# *** amount of allowed actions: 1.0
#
# Calculating reward for action: flight 0, aircraft 0
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -0 penalty for 0 new cancelled flights: set()
#   -0.2 penalty for inaction with remaining conflicts
#   -42.0 penalty for time progression
# --------------------------------
# Total reward: -42.2
# --------------------------------
# action index:
# 0
# action mapped:
# (0, 0)
# Action taken: (0, 0), Reward: -42.2
# Step 7:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': {'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 0.8574288238870814}}
# *** amount of allowed actions: 57.0
#
# Calculating reward for action: flight 13, aircraft 2
#   -0.0 penalty for 0.0 minutes of additional delay (capped at 25000000)
#   -5000 penalty for 1 new cancelled flights: {15}
#   -0 penalty for inaction with remaining conflicts
#   +12.9 bonus for proactive action (258.0 minutes ahead)
#   -48.0 penalty for time progression
#   -100 penalty for tail swap
# --------------------------------
# Total reward: -5135.1
# --------------------------------
# action index:
# 93
# action mapped:
# (13, 2)
# Action taken: (13, 2), Reward: -5135.1
# Step 8:
# **updated_alt_aircraft_dict:
# {'B737#4': {'StartDate': '28/09/24', 'StartTime': '12:05', 'EndDate': '28/09/24', 'EndTime': '17:17', 'Probability': 1.0}, 'B737#3': [{'StartDate': '28/09/24', 'StartTime': '12:29', 'EndDate': '28/09/24', 'EndTime': '17:33', 'Probability': 1.0}]}
# *** amount of allowed actions: 57.0
#
# Calculating reward for action: flight 10, aircraft 4
#   -4450.0 penalty for 89.0 minutes of additional delay (capped at 25000000)
#   -5000 penalty for 1 new cancelled flights: {12}
#   -0 penalty for inaction with remaining conflicts
#   +8.4 bonus for proactive action (168.0 minutes ahead)
#   -54.0 penalty for time progression
#   +60000 final reward for resolving 2 real (non-cancelled) conflicts at scenario end: [10.0, 13.0]
#   -100 penalty for tail swap
# --------------------------------
# Total reward: 50404.4
# --------------------------------
# action index:
# 74
# action mapped:
# (10, 4)
# Action taken: (10, 4), Reward: 50404.4
# ================================================
# Final state:
# Total Reward: 40010.3
# Total Steps: 9
# HBox(children=(Button(description='⬅️', layout=Layout(width='40px'), style=ButtonStyle()), Button(description=…
# Output()
